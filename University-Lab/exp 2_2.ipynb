# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Create a graph
# G = nx.Graph()
# G.add_edges_from([(1, 2), (2, 3), (3, 1), (2, 4), (4, 5)])

G=nx.karate_club_graph()

# Count the number of unstable triangles
unstable_triangles = 0
for node in G.nodes():
    neighbors = set(G.neighbors(node))
    for neighbor in neighbors:
        for second_neighbor in neighbors:
            if second_neighbor != neighbor and not G.has_edge(neighbor, second_neighbor):
                unstable_triangles += 1
print("Number of unstable triangles:", unstable_triangles)

# Display the graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=500)
plt.title('Harikesh Kumar Sharma (21BCS2127)')
plt.show()
# Out:
# Number of unstable triangles: 786
